# %%
# Count rate vs distance. We expect 1/r^2 behavior!
import matplotlib.pyplot as plt
import numpy as np
import scipy.constants as sp

data_input = np.loadtxt("distance.txt", delimiter=",")
data = np.transpose(data_input) # depends on format of txt file

trials = 5
distance = [i+1 for i in range(trials)] # testing 1 cm to $trial$ cm
count_rate = data[0]

plt.title("Count Rate vs Distance")
plt.xlabel("Distance (cm)")
plt.ylabel("Count Rate (counts/minute)")

# yerr = error TBD
# xerr = error

plt.scatter(distance, countrate)
# plt.errorbar(x_data, y_data, yerr = yerr, xerr = xerr, fmt ='o')

# plt.savefig("count_distance.jpg", dpi=1080, bbox_inches="tight")

plt.show()

# %%
# Linearized count rate vs distance. Expected slope = 2
import matplotlib.pyplot as plt
import numpy as np
import scipy.constants as sp

data_input = np.loadtxt("distance.txt", delimiter=",")
data = np.transpose(data_input) # depends on format of txt file

trials = 5
count_rate = data[0]
distance = [i+1 for i in range(trials)] # testing 1 cm to $trial$ cm
count_rate = np.log(count_rate)
distance = np.log(distance)


plt.title("Log-log plot of count rate vs distance")
plt.xlabel("Distance (cm)")
plt.ylabel("Count Rate (counts/minute)")

# yerr = error TBD
# xerr = error
# plt.loglog(count_rate, distance)

plt.scatter(distance, countrate)
plt.errorbar(x_data, y_data, yerr = yerr, xerr = xerr, fmt ='o')

# plt.savefig("count_distance.jpg", dpi=1080, bbox_inches="tight")

plt.show()

# %%
# Count rate vs material thickness - lead, aluminium, cardboard, paper. Repeat for each material
import matplotlib.pyplot as plt
import numpy as np
import scipy.constants as sp

data_input = np.loadtxt("material_thickness.txt", delimiter=",")
data = np.transpose(data_input) # modify depending on format

sheets = 2
thickness = 1 # need to measure this
count_rate = data[0]
thickness = [thickness*(i+1) for i in range(sheets)]

plt.title("Count Rate vs Lead Sheet Thickness")
plt.xlabel("Thickness (cm)")
plt.ylabel("Count Rate (counts/minute)")

# yerr = error
# xerr = error

plt.scatter(x_data, y_data)
plt.errorbar(x_data, y_data, yerr = yerr, xerr = xerr, fmt ='o')

# plt.savefig("lead.jpg", dpi=1080, bbox_inches="tight")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.constants as sp

data_input = np.loadtxt("tube_efficiency.txt", delimiter=",")
data = np.transpose(data_input) # modify depending on format

count_rate = data[0]
expected_count_rate = []
tube_efficiency = [i / j for i, j in zip(count_Rate, expected_count_rate)]
voltage = [i for i in range(350, 450, 25)]

plt.title("Tube Efficiency vs Voltage")
plt.xlabel("Voltage (V)")
plt.ylabel("Tube Efficiency [count rate / expected count rate")

# yerr = error
# xerr = error

plt.scatter(x_data, y_data)
plt.errorbar(x_data, y_data, yerr = yerr, xerr = xerr, fmt ='o')

# plt.savefig("tube_efficiency.jpg", dpi=1080, bbox_inches="tight")

plt.show()
